# %%
import pandas as pd

# %%
df = pd.read_csv('API_AG.LND.AGRI.ZS_DS2_en_csv_v2_10225261.csv')
df.head()
# Out:
#   Country Name Country Code                      Indicator Name  \
# 0        Aruba          ABW  Agricultural land (% of land area)
# 1  Afghanistan          AFG  Agricultural land (% of land area)
# 2       Angola          AGO  Agricultural land (% of land area)
# 3      Albania          ALB  Agricultural land (% of land area)
# 4      Andorra          AND  Agricultural land (% of land area)
#
#    Indicator Code  1960       1961       1962       1963       1964  \
# 0  AG.LND.AGRI.ZS   NaN  11.111111  11.111111  11.111111  11.111111
# 1  AG.LND.AGRI.ZS   NaN  57.745918  57.837821  57.914407  58.010906
# 2  AG.LND.AGRI.ZS   NaN  45.857063  45.881126  45.897169  45.921232
# 3  AG.LND.AGRI.ZS   NaN  44.963504  44.963504  45.000000  44.890511
# 4  AG.LND.AGRI.ZS   NaN  55.319149  55.319149  55.319149  55.319149
#
#         1965     ...            2009       2010       2011       2012  \
# 0  11.111111     ...       11.111111  11.111111  11.111111  11.111111
# ...

# %%
df.drop(columns=df.columns[3:-4], inplace=True)

# %%
df.drop(columns=df.columns[4:], inplace=True)

# %%
df.head()
# Out:
#   Country Name Country Code                      Indicator Name       2015
# 0        Aruba          ABW  Agricultural land (% of land area)  11.111111
# 1  Afghanistan          AFG  Agricultural land (% of land area)  58.067580
# 2       Angola          AGO  Agricultural land (% of land area)  47.477340
# 3      Albania          ALB  Agricultural land (% of land area)  42.857664
# 4      Andorra          AND  Agricultural land (% of land area)  40.021277

# %%
df.to_csv('agricultural_land_cleaned.csv', index=False)
