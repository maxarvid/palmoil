# %%
import pandas as pd
import matplotlib as plt

# %matplotlib inline

# %%
df = pd.read_csv('UNdata_Export_20181127_011429219.csv')
df.head()
# Out:
#   Country or Area                        Element    Year    Unit    Value  \
# 0     Afghanistan  Food supply quantity (tonnes)  2013.0  tonnes  64000.0
# 1     Afghanistan  Food supply quantity (tonnes)  2012.0  tonnes  60600.0
# 2     Afghanistan  Food supply quantity (tonnes)  2011.0  tonnes  51100.0
# 3     Afghanistan  Food supply quantity (tonnes)  2010.0  tonnes  58500.0
# 4     Afghanistan  Food supply quantity (tonnes)  2009.0  tonnes  52900.0
#
#   Value Footnotes
# 0               S
# 1               S
# 2               S
# 3               S
# 4               S

# %%
df.shape
# Out:
# (43900, 6)

# %%
df.dtypes
# Out:
# Country or Area     object
# Element             object
# Year               float64
# Unit                object
# Value              float64
# Value Footnotes     object
# dtype: object

# %%
df.head()
# Out:
#   Country or Area                        Element    Year    Unit    Value  \
# 0     Afghanistan  Food supply quantity (tonnes)  2013.0  tonnes  64000.0
# 1     Afghanistan  Food supply quantity (tonnes)  2012.0  tonnes  60600.0
# 2     Afghanistan  Food supply quantity (tonnes)  2011.0  tonnes  51100.0
# 3     Afghanistan  Food supply quantity (tonnes)  2010.0  tonnes  58500.0
# 4     Afghanistan  Food supply quantity (tonnes)  2009.0  tonnes  52900.0
#
#   Value Footnotes
# 0               S
# 1               S
# 2               S
# 3               S
# 4               S

# %%
df[df['Country or Area'] == 'Italy']
# Out:
#       Country or Area                             Element    Year  \
# 20196           Italy       Food supply quantity (tonnes)  2013.0
# 20197           Italy       Food supply quantity (tonnes)  2012.0
# 20198           Italy       Food supply quantity (tonnes)  2011.0
# 20199           Italy       Food supply quantity (tonnes)  2010.0
# 20200           Italy       Food supply quantity (tonnes)  2009.0
# 20201           Italy       Food supply quantity (tonnes)  2008.0
# 20202           Italy       Food supply quantity (tonnes)  2007.0
# 20203           Italy       Food supply quantity (tonnes)  2006.0
# 20204           Italy       Food supply quantity (tonnes)  2005.0
# 20205           Italy       Food supply quantity (tonnes)  2004.0
# 20206           Italy       Food supply quantity (tonnes)  2003.0
# 20207           Italy       Food supply quantity (tonnes)  2002.0
# 20208           Italy       Food supply quantity (tonnes)  2001.0
# ...

# %%
df[df.Unit == 'tonnes'].groupby('Year').mean().plot(kind='bar', y='Value', color='grey')

# %%
df.Element.value_counts()
# Out:
# Food supply quantity (tonnes)                                                   8101
# Food supply quantity (kg/capita/yr)                                             8101
# Fat supply quantity (g/capita/day)                                              8048
# Food supply quantity (g/capita/day)                                             8048
# Food supply (kcal/capita/day)                                                   8048
# Protein supply quantity (g/capita/day)                                          3550
# Aggregate, may include official, semi-official, estimated or calculated data       1
# Standardized data                                                                  1
# Footnote                                                                           1
# Calculated data                                                                    1
# Name: Element, dtype: int64

# %%
df.Year.value_counts()
# Out:
# 2013.0    846
# 2011.0    846
# 2010.0    846
# 2009.0    846
# 2008.0    846
# 2007.0    846
# 2006.0    846
# 2012.0    846
# 1998.0    840
# 1992.0    840
# 1993.0    840
# 1995.0    840
# 1996.0    840
# 1997.0    840
# 1994.0    840
# 1999.0    840
# 2003.0    840
# 2000.0    840
# 2004.0    840
# 2005.0    840
# 2001.0    840
# 2002.0    840
# 1991.0    823
# 1990.0    823
# 1975.0    818
# 1968.0    818
# 1973.0    818
# 1972.0    818
# 1971.0    818
# 1970.0    818
# 1969.0    818
# 1966.0    818
# 1967.0    818
# 1965.0    818
# 1964.0    818
# 1963.0    818
# 1962.0    818
# 1974.0    818
# 1987.0    818
# 1976.0    818
# 1977.0    818
# 1978.0    818
# 1979.0    818
# 1980.0    818
# 1981.0    818
# 1982.0    818
# 1983.0    818
# 1984.0    818
# 1985.0    818
# 1986.0    818
# 1988.0    818
# 1989.0    818
# 1961.0    818
# Name: Year, dtype: int64

# %%
df[(df['Country or Area'] == 'United States of America') & (df['Year'] == 1994.0)]
# Out:
#                 Country or Area                                 Element  \
# 40761  United States of America           Food supply quantity (tonnes)
# 40814  United States of America     Food supply quantity (kg/capita/yr)
# 40867  United States of America     Food supply quantity (g/capita/day)
# 40920  United States of America           Food supply (kcal/capita/day)
# 40973  United States of America  Protein supply quantity (g/capita/day)
# 41026  United States of America      Fat supply quantity (g/capita/day)
#
#          Year             Unit     Value Value Footnotes
# 40761  1994.0           tonnes  39231.31               S
# 40814  1994.0               kg      0.15              Fc
# 40867  1994.0     g/capita/day      0.41              Fc
# 40920  1994.0  kcal/capita/day      3.00              Fc
# 40973  1994.0     g/capita/day      0.00              Fc
# 41026  1994.0     g/capita/day      0.37              Fc

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-848b80e64df8> in <module>()
# ----> 1 df.plot()
#
# NameError: name 'df' is not defined
